# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.9/644.9 kB 9.9 MB/s eta 0:00:00
# ...

# %%
# !pip install git+https://github.com/ultralytics/ultralytics.git@main
# Out:
# ...
#   Cloning https://github.com/ultralytics/ultralytics.git (to revision main) to /tmp/pip-req-build-nvqqoio5
#   Running command git clone --filter=blob:none --quiet https://github.com/ultralytics/ultralytics.git /tmp/pip-req-build-nvqqoio5
#   Resolved https://github.com/ultralytics/ultralytics.git to commit 168e536faee4b8fffc721cdb89e266e391f78fae
#   Preparing metadata (setup.py) ... done
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.yaml')
model = YOLO('yolov8n.pt')
model = YOLO('yolov8n.yaml').load('yolov8n.pt')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
results = model.train(data='/content/drive/MyDrive/extracted folder dataset/data.yaml', epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import ultralytics
ultralytics.utils.metrics.ConfusionMatrix

# %%
metrics = model.val()
metrics.box.map50
metrics.box.map75
metrics.box.maps
# Out:
# Ultralytics YOLOv8.0.206 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/extracted folder dataset/valid/labels.cache... 649 images, 0 backgrounds, 0 corrupt: 100%|██████████| 649/649 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 41/41 [00:13<00:00,  3.15it/s]
#                    all        649        649      0.917      0.885      0.958      0.864
#                  awake        649        398      0.925      0.965      0.972      0.859
#                 drowsy        649        228      0.881      0.907      0.954      0.863
#                  sleep        649         23      0.945      0.783      0.947      0.871
# Speed: 0.6ms preprocess, 4.8ms inference, 0.0ms loss, 3.0ms postprocess per image
# Results saved to runs/detect/train2
# ...

# %%
metrics.box.maps
# Out:
# array([    0.85923,     0.86294,     0.87072])

# %%
import IPython
from IPython.display import Image

# %%
Image(filename=f'/content/runs/detect/train/confusion_matrix.png',width=800)

# %%
Image(filename=f'/content/runs/detect/train/results.png')

# %%
model.predict('/content/download (2).jpeg', save=True, imgsz=320, conf=0.5)
# Out:
# image 1/1 /content/download (2).jpeg: 256x320 1 awake, 499.1ms
# Speed: 2.0ms preprocess, 499.1ms inference, 3.2ms postprocess per image at shape (1, 3, 256, 320)
# Results saved to runs/detect/train9
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'awake', 1: 'drowsy', 2: 'sleep'}
#  orig_img: array([[[236, 237, 235],
#          [236, 237, 235],
#          [236, 237, 235],
#          ...,
#          [248, 244, 243],
#          [248, 244, 243],
#          [248, 244, 243]],
#
#         [[236, 237, 235],
#          [236, 237, 235],
#          [236, 237, 235],
#          ...,
#          [248, 244, 243],
#          [248, 244, 243],
#          [248, 244, 243]],
#
#         [[236, 237, 235],
#          [236, 237, 235],
#          [236, 237, 235],
#          ...,
#          [248, 244, 243],
#          [248, 244, 243],
#          [248, 244, 243]],
#
#         ...,
#
# ...

# %%
Image(filename=f'/content/runs/detect/train9/download (2).jpeg',width=400)

# %%
model.predict('/content/drive/MyDrive/extracted folder dataset/valid/images/frame_1696511804342_jpg.rf.38218f8e38972a822931634dd83cfda8.jpg',save=True,imgsz=320,conf=0.5)
# Out:
# image 1/1 /content/drive/MyDrive/extracted folder dataset/valid/images/frame_1696511804342_jpg.rf.38218f8e38972a822931634dd83cfda8.jpg: 320x320 1 drowsy, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 320)
# Results saved to runs/detect/train8
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'awake', 1: 'drowsy', 2: 'sleep'}
#  orig_img: array([[[120, 120, 144],
#          [120, 120, 144],
#          [118, 120, 144],
#          ...,
#          [183, 192, 202],
#          [183, 192, 202],
#          [183, 192, 202]],
#
#         [[120, 120, 144],
#          [120, 120, 144],
#          [118, 120, 144],
#          ...,
#          [183, 192, 202],
#          [183, 192, 202],
#          [183, 192, 202]],
#
#         [[120, 121, 142],
#          [120, 121, 142],
#          [118, 121, 142],
#          ...,
# ...

# %%
Image(filename='/content/runs/detect/train8/frame_1696511804342_jpg.rf.38218f8e38972a822931634dd83cfda8.jpg',width=400)

# %%
Image(filename='/content/runs/detect/train6/frame_1696511824248_jpg.rf.4ee2de5a92750bc614859031cc576726.jpg',width=400)

# %%
from google.colab import files
import shutil

# %%
shutil.make_archive("/content/runs",'zip',"/content/runs")
# Out:
# '/content/runs.zip'

# %%
files.download("/content/runs.zip")
